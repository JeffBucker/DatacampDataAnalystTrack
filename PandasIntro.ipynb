# %%
import pandas as pd

# %%
df = pd.read_csv('eng51403.csv')    # we import the .csv content in a pd dataframe object called 'df'

# %%
print(df.info())   # renseigne sur la structure de la table
print(df.head())   # montre les 5 premières ligne de la table

# %%
df['SEDOL']    # A way to select columns
df.SEDOL   # Another way

# %%
df['Closing Price'] > 100    # in order to check a value
df['SEDOL'] == 'BQZCBZ4'

# %%
price_over_100 = df[df['Closing Price'] > 100]   # in order to filter rows 
print(price_over_100)
# Out:
#    Last Modified Effective Date Cons Code  \
# 1     13/03/2023     20/03/2023   C152145
# 2     13/03/2023     20/03/2023    C69407
# 6     13/03/2023     20/03/2023    C17244
# 9     13/03/2023     20/03/2023   C144830
# 13    13/03/2023     20/03/2023    C69878
# 16    13/03/2023     20/03/2023    C84965
# 22    13/03/2023     20/03/2023   C138921
# 24    13/03/2023     20/03/2023   C168890
# 25    13/03/2023     20/03/2023    C85476
# 27    13/03/2023     20/03/2023    C00857
# 31    13/03/2023     20/03/2023   C144902
# 32    13/03/2023     20/03/2023    C17690
# 40    13/03/2023     20/03/2023   C182513
# 41    13/03/2023     20/03/2023    C24181
# 42    13/03/2023     20/03/2023   C164671
# 45    13/03/2023     20/03/2023   C170084
# 48    13/03/2023     20/03/2023    C85479
#
#                        Constituent Name    SEDOL      CUSIP Country Code  \
# 1                  AEON REIT Investment  BFSSCF9        NaN           JA
# ...
